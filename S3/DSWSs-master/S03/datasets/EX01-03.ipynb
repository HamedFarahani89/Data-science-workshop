# %%
# %matplotlib inline

import numpy as np
import pylab as plt
import pandas as pd

#Open data
dftesla = pd.read_csv('tesla-stock-price.csv')

# dftesla.head()

dftesla['avg'] = dftesla[['high', 'low']].mean(axis=1)

# %%
dftesla.head()
# Out:
#          date   close         volume    open    high       low        avg
# 0       11:34  270.49      4,787,699  264.50  273.88  262.2400  268.06000
# 1  2018/10/15  259.59   6189026.0000  259.06  263.28  254.5367  258.90835
# 2  2018/10/12  258.78   7189257.0000  261.00  261.99  252.0100  257.00000
# 3  2018/10/11  252.23   8128184.0000  257.53  262.25  249.0300  255.64000
# 4  2018/10/10  256.88  12781560.0000  264.61  265.51  247.7700  256.64000

# %%
x = dftesla['date'].values
y = dftesla['avg'].values

# %%
plt.plot(x,y)

# %%
f, ax = plt.subplots(figsize=(20,10))
ax.plot(x,y,'b')
ax.set_xticks(x[::150]);
plt.xticks(rotation=90)
ax

# %%
y = dftesla['avg'].values
Y=y.tolist()
count=0
x=350
for i in range(1,len(Y)-1):
    if Y[i]<=x and Y[i+1]>x:
        count+=1
count
# Out:
# 13

# %%
# %matplotlib inline

import numpy as np
import pylab as plt
import pandas as pd

#Open data
dftesla = pd.read_csv('tesla-stock-price.csv')

# dftesla.head()

dftesla['avg'] = dftesla[['high', 'low']].mean(axis=1)
y = dftesla['avg'].values
Y=y.tolist()
counta=0
countb=0
Y[10]

# def counting(Y):    i=0
# while Y[i]>250:
#     i+=1
#     break
#     counta+=1
# # counting(Y)    
# while Y[i]<250:
#     i+=1
#     break
#     countb+=1
# print(counta)  
i=0
while Y[i]>250:
    i+=1
    if Y[i]<250:
        counta+=1
        break
while Y[i]<250:
    i+=1
    if Y[i]<250:
        countb+=1
        break   
#     if Y[i]<250:
#         print("bye")
    
print(i)
print(counta)
print(countb)
# Out:
# 404
# 1
# 1

# %% [markdown]
# Last version for python run

# %%
import numpy as np
import pylab as plt
import pandas as pd
import sys


dftesla = pd.read_csv(sys.argv[0])
dftesla['avg'] = dftesla[['high', 'low']].mean(axis=1)
y = dftesla['avg'].values
Y=y.tolist()
count=0
x=350
for i in range(1,len(Y)-1):
    if Y[i]<=x and Y[i+1]>x:
        count+=1
count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-e565831dd71c> in <module>
#       6
#       7 dftesla = pd.read_csv(sys.argv[0])
# ----> 8 dftesla['avg'] = dftesla[['high', 'low']].mean(axis=1)
#       9 y = dftesla['avg'].values
#      10 Y=y.tolist()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...
