# %% [markdown]
# 3. write a code to fit a sinusoidal function like f(x)=a*sin(b*x) to a given data.
#
# input:
#     The data file name (string)
#         (like the example in datasets directory, exercise.npy)
# output:
#     a (float)
#     b (float)

# %%
import numpy as np
import pylab as plt
import math
EX = np.load('exercise.npy')
EXX = []
EXY = []

for i in range(len(EX)):
     EXX.append(EX[i][0])
        
for i in range(len(EX)):
     EXY.append(EX[i][1])



plt.plot(EXX, amplitude)

plt.plot(EXX,EXY,'r--')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-5d5d4215de75> in <module>
#      16
#      17
# ---> 18 amplitude   = a*np.sin(b*EXX)
#      19
#      20 plt.plot(EXX, amplitude)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
def func(x, a, b):
    return a * np.sin(b * x)

# %%
dis=[]
for i in range(len(EXX)):
    for a in np.arange(-2, 2, 0.1):
        for b in np.arange(-2, 2, 0.1):
            dis.append(EXY[i]- (a * np.sin(b * EXX[i])))
# Out:
# [-1.0708778522309075,
#  -1.144883173954373,
#  -1.1999782603359346,
#  -1.2356126194844814,
#  -1.2514302046625545,
#  -1.247272971787653,
#  -1.2231824585564643,
#  -1.1793993694139298,
#  -1.1163611705139962,
#  -1.034697718702414,
#  -0.9352249681953362,
#  -0.8189368178345096,
#  -0.6869951803785881,
#  -0.5407183730549243,
#  -0.3815679453696128,
#  -0.21113407578794774,
#  -0.03111968319684244,
#  0.15667658809777962,
#  0.3503783398303366,
#  0.548050168126803,
#  0.7477170014204595,
#  0.9473838347141159,
#  1.1450556630105821,
#  1.3387574147431391,
#  1.5265536860377609,
#  1.706568078628866,
#  1.8770019482105305,
#  2.036152375895842,
#  2.182429183219505,
#  2.3143708206754257,
#  2.4306589710362516,
#  2.530131721543329,
#  2.6117951733549107,
#  2.6748333722548434,
#  2.718616461397377,
#  2.7427069746285655,
#  2.7468642075034664,
#  2.731046622325392,
#  2.695412263176845,
#  2.640317176795283,
#  -0.9799481095483393,
#  -1.0502531651856315,
#  -1.102593497248115,
# ...

# %%
time        = np.arange(0, 10, 0.1);

amplitude   = np.sin(2*time)

plt.plot(time, amplitude)

plot.title('Sine wave')

plot.xlabel('Time')

plot.ylabel('Amplitude = sin(time)')

plot.axhline(y=0, color='k')

plot.show()

# %%
a=1.1
b=1.07       



time        = np.arange(0, 10, 0.1);

amplitude   = a*np.sin(b*time)

plt.plot(time, amplitude)

plot.title('Sine wave')

plot.xlabel('Time')

plot.ylabel('Amplitude = sin(time)')

plot.axhline(y=0, color='k')

plt.plot(EXX,EXY,'r--')

plot.show()

# %%
a,b = 1,1
dis=[]
for i in range(len(EXX)):
    dis.append(EXY- (a * np.sin(b * EXX[i]) ))
dis

# %%
import os
import numpy as np
import pylab as plt
import math


df=np.load('exercise.npy')
x_obs=df[:,0]
y_obs=df[:,1]


def model(x,a,b):
    return a*math.sin(b*x)
model2 = np.vectorize(model) 



listmin=[]
listaas=[]
listbbs=[]


for b in np.arange(-2,3,0.1):
    for a in np.arange(-2,3,0.1):
        y_pointer=model2(x_obs,a,b)

        loss=np.sum((y_pointer-y_obs)**2)
        listmin.append(loss)
        listaas.append(a)
        listbbs.append(b)

listaas[listmin.index(min(listmin))], listbbs[listmin.index(min(listmin))]
# Out:
# (1.0000000000000027, 1.0000000000000027)

# %%
A=[1,2,3,4]
A.index(2)
# Out:
# 1

# %%
import numpy as np
import pylab as plt
import math
EX = np.load('exercise.npy')
EXX = []
EXY = []

for i in range(len(EX)):
     EXX.append(EX[i][0])
        
for i in range(len(EX)):
     EXY.append(EX[i][1])


plt.plot(EXX,EXY,'r--')

# %%
def func(x, a, b):
    return a * np.sin(b * x) 

plt.plot(x,y_theory,'b')
da=0.1
for i in range(10):
    y_theory = func(EXX,1,1)
